# %%
import tensorflow as tf
import datetime
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

# %%
def load_data(data_directory):
    images = []
    labels = []
    classes = []
    label_encoder = LabelEncoder()

    for class_name in os.listdir(data_directory):
        class_path = os.path.join(data_directory, class_name)
        classes.append(class_name)

        for filename in os.listdir(class_path):
            filepath = os.path.join(class_path, filename)
            img = cv2.imread(filepath)
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
                img = cv2.resize(img, (224, 224))
                img = img / 255.0
                images.append(img)
                labels.append(class_name)

    images = np.array(images)
    labels = label_encoder.fit_transform(labels) 

    return images, labels, classes

# Update the path to your dataset
data_directory = 'D:/3year/1sem/MLDL/Assignment 1/code/dataset'
images, labels, classes = load_data(data_directory)

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=[classes[label] for label in labels])  
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
classes = np.unique(classes)

# %%
#define the convnet
model = Sequential()
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(16, (3, 3), padding='same', input_shape=(224, 224, 3)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
# FLATTERN => DENSE => RELU => DROPOUT
model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dense(6, activation='softmax'))

model.summary()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
datagen = ImageDataGenerator(
    rotation_range=30,         # Randomly rotate images by 20 degrees
    #brightness_range=[0., 0.5],  # Adjust brightness between 10% and 200%
    width_shift_range=0.1,     # Randomly shift images horizontally by 20% of the width
    height_shift_range=0.1,    # Randomly shift images vertically by 20% of the height
    shear_range=0.1,           # Shear intensity
    zoom_range=0.3,            # Randomly zoom into images
    horizontal_flip=True,      # Randomly flip images horizontally
    vertical_flip=True,        # Randomly flip images vertically
)
datagen1 = ImageDataGenerator()

train_generator = datagen.flow(X_train, y_train, batch_size=20)
val_generator = datagen1.flow(X_test, y_test, batch_size=20)
# Out:
# c:\Users\tesme\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,718,150 (98.11 MB)
#  Trainable params: 25,718,150 (98.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
index = np.random.randint(0, len(X_train))

# Select the original image
original_image = (X_train[index]*255).astype(np.uint8)
original_image = original_image.astype(np.uint8)

# Reshape the selected image to (1, height, width, channels) to make it a batch of size 1
original_image = np.expand_dims(original_image, axis=0)

# Create an iterator for the batch (with only one sample)
iterator = datagen.flow(original_image, batch_size=1)

# Generate augmented images
augmented_images = (iterator.__next__()).astype(np.uint8)

# Display the original and augmented images
plt.figure(figsize=(8, 4))

# Original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(original_image[0])
plt.axis('off')

# Augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
plt.imshow(augmented_images[0] ,vmax = 1., vmin = 0)
plt.axis('off')

plt.show()

# %%
history = model.fit(train_generator, epochs=150, validation_data=val_generator)
# Out:
# Epoch 1/150
# c:\Users\tesme\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.1512 - loss: 3.6745 - val_accuracy: 0.2278 - val_loss: 1.7651
# Epoch 2/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.2152 - loss: 1.7325 - val_accuracy: 0.3056 - val_loss: 1.6712
# Epoch 3/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.3455 - loss: 1.6187 - val_accuracy: 0.3222 - val_loss: 1.5657
# Epoch 4/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 986ms/step - accuracy: 0.3860 - loss: 1.4686 - val_accuracy: 0.3167 - val_loss: 1.5383
# Epoch 5/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 994ms/step - accuracy: 0.4348 - loss: 1.3758 - val_accuracy: 0.3833 - val_loss: 1.4231
# Epoch 6/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 978ms/step - accuracy: 0.4075 - loss: 1.3591 - val_accuracy: 0.4444 - val_loss: 1.4229
# Epoch 7/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 981ms/step - accuracy: 0.5011 - loss: 1.2389 - val_accuracy: 0.4389 - val_loss: 1.4477
# Epoch 8/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 985ms/step - accuracy: 0.5071 - loss: 1.1984 - val_accuracy: 0.4444 - val_loss: 1.3242
# Epoch 9/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 990ms/step - accuracy: 0.5648 - loss: 1.1208 - val_accuracy: 0.4389 - val_loss: 1.4090
# Epoch 10/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 983ms/step - accuracy: 0.5656 - loss: 1.1339 - val_accuracy: 0.5167 - val_loss: 1.2486
# Epoch 11/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 986ms/step - accuracy: 0.5583 - loss: 1.1445 - val_accuracy: 0.4556 - val_loss: 1.3517
# Epoch 12/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.5822 - loss: 1.0916 - val_accuracy: 0.5000 - val_loss: 1.2026
# Epoch 13/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6370 - loss: 0.9481 - val_accuracy: 0.4944 - val_loss: 1.4778
# Epoch 14/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6501 - loss: 0.9426 - val_accuracy: 0.5111 - val_loss: 1.2075
# Epoch 15/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6278 - loss: 0.9778 - val_accuracy: 0.6167 - val_loss: 1.1427
# Epoch 16/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.6622 - loss: 0.9557 - val_accuracy: 0.5222 - val_loss: 1.2600
# Epoch 17/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6651 - loss: 0.8919 - val_accuracy: 0.6167 - val_loss: 1.0365
# Epoch 18/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.6785 - loss: 0.8066 - val_accuracy: 0.5833 - val_loss: 1.1920
# Epoch 19/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6573 - loss: 0.8724 - val_accuracy: 0.6444 - val_loss: 1.0238
# Epoch 20/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6963 - loss: 0.8239 - val_accuracy: 0.6000 - val_loss: 1.1233
# Epoch 21/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7111 - loss: 0.8079 - val_accuracy: 0.6833 - val_loss: 0.9798
# Epoch 22/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6942 - loss: 0.7474 - val_accuracy: 0.6444 - val_loss: 1.1198
# Epoch 23/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6731 - loss: 0.7609 - val_accuracy: 0.6000 - val_loss: 1.0328
# Epoch 24/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7295 - loss: 0.6805 - val_accuracy: 0.6667 - val_loss: 0.9468
# Epoch 25/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.7251 - loss: 0.7311 - val_accuracy: 0.5556 - val_loss: 1.1835
# Epoch 26/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7019 - loss: 0.7801 - val_accuracy: 0.6389 - val_loss: 0.9891
# Epoch 27/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7155 - loss: 0.7113 - val_accuracy: 0.6833 - val_loss: 0.9801
# Epoch 28/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7423 - loss: 0.6633 - val_accuracy: 0.7111 - val_loss: 0.9154
# Epoch 29/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7519 - loss: 0.6691 - val_accuracy: 0.6556 - val_loss: 1.0347
# Epoch 30/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7274 - loss: 0.6635 - val_accuracy: 0.6500 - val_loss: 0.9268
# Epoch 31/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.7720 - loss: 0.5736 - val_accuracy: 0.6500 - val_loss: 0.9883
# Epoch 32/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7959 - loss: 0.6094 - val_accuracy: 0.6833 - val_loss: 0.9349
# Epoch 33/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.7867 - loss: 0.5899 - val_accuracy: 0.7056 - val_loss: 0.9026
# Epoch 34/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8078 - loss: 0.5235 - val_accuracy: 0.7000 - val_loss: 0.8462
# Epoch 35/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7786 - loss: 0.6041 - val_accuracy: 0.7333 - val_loss: 0.7647
# Epoch 36/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7975 - loss: 0.5751 - val_accuracy: 0.5889 - val_loss: 0.9830
# Epoch 37/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7746 - loss: 0.6390 - val_accuracy: 0.7056 - val_loss: 0.7888
# Epoch 38/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8149 - loss: 0.5191 - val_accuracy: 0.7222 - val_loss: 0.8958
# Epoch 39/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8086 - loss: 0.5148 - val_accuracy: 0.6778 - val_loss: 0.8529
# Epoch 40/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7889 - loss: 0.5390 - val_accuracy: 0.7222 - val_loss: 0.7833
# Epoch 41/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8422 - loss: 0.4267 - val_accuracy: 0.7278 - val_loss: 0.8513
# Epoch 42/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8495 - loss: 0.4641 - val_accuracy: 0.7000 - val_loss: 0.8811
# Epoch 43/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8313 - loss: 0.4619 - val_accuracy: 0.7278 - val_loss: 0.8209
# Epoch 44/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8216 - loss: 0.4858 - val_accuracy: 0.7556 - val_loss: 0.7261
# Epoch 45/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8515 - loss: 0.3960 - val_accuracy: 0.7667 - val_loss: 0.7214
# Epoch 46/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8626 - loss: 0.4124 - val_accuracy: 0.7444 - val_loss: 0.7340
# Epoch 47/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8448 - loss: 0.4111 - val_accuracy: 0.7111 - val_loss: 0.7837
# Epoch 48/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8295 - loss: 0.4616 - val_accuracy: 0.6556 - val_loss: 0.8621
# Epoch 49/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8090 - loss: 0.5152 - val_accuracy: 0.7667 - val_loss: 0.7065
# Epoch 50/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8683 - loss: 0.3147 - val_accuracy: 0.8278 - val_loss: 0.5964
# Epoch 51/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8524 - loss: 0.3818 - val_accuracy: 0.7778 - val_loss: 0.6869
# Epoch 52/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8430 - loss: 0.4083 - val_accuracy: 0.7889 - val_loss: 0.6292
# Epoch 53/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8900 - loss: 0.3212 - val_accuracy: 0.7944 - val_loss: 0.6733
# Epoch 54/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8403 - loss: 0.4468 - val_accuracy: 0.7500 - val_loss: 0.7194
# Epoch 55/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8629 - loss: 0.4197 - val_accuracy: 0.7500 - val_loss: 0.7922
# Epoch 56/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8709 - loss: 0.3677 - val_accuracy: 0.7722 - val_loss: 0.6883
# Epoch 57/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9030 - loss: 0.2544 - val_accuracy: 0.8000 - val_loss: 0.6013
# Epoch 58/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8824 - loss: 0.3435 - val_accuracy: 0.8000 - val_loss: 0.6214
# Epoch 59/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.8889 - loss: 0.3178 - val_accuracy: 0.7722 - val_loss: 0.6557
# Epoch 60/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8907 - loss: 0.2937 - val_accuracy: 0.8278 - val_loss: 0.6294
# Epoch 61/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9139 - loss: 0.2017 - val_accuracy: 0.8111 - val_loss: 0.6666
# Epoch 62/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9163 - loss: 0.2613 - val_accuracy: 0.7278 - val_loss: 0.7433
# Epoch 63/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8837 - loss: 0.3105 - val_accuracy: 0.8000 - val_loss: 0.6214
# Epoch 64/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8820 - loss: 0.3122 - val_accuracy: 0.7667 - val_loss: 0.6324
# Epoch 65/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8950 - loss: 0.3035 - val_accuracy: 0.7944 - val_loss: 0.7101
# Epoch 66/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9042 - loss: 0.2641 - val_accuracy: 0.8278 - val_loss: 0.5577
# Epoch 67/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9291 - loss: 0.2121 - val_accuracy: 0.8389 - val_loss: 0.5525
# Epoch 68/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8911 - loss: 0.2882 - val_accuracy: 0.7667 - val_loss: 0.7862
# Epoch 69/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8201 - loss: 0.5146 - val_accuracy: 0.7611 - val_loss: 0.7986
# Epoch 70/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8601 - loss: 0.4167 - val_accuracy: 0.7611 - val_loss: 0.6477
# Epoch 71/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8990 - loss: 0.2489 - val_accuracy: 0.8333 - val_loss: 0.5952
# Epoch 72/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9261 - loss: 0.2298 - val_accuracy: 0.8167 - val_loss: 0.6365
# Epoch 73/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9263 - loss: 0.2100 - val_accuracy: 0.8333 - val_loss: 0.5729
# Epoch 74/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9042 - loss: 0.2861 - val_accuracy: 0.8389 - val_loss: 0.5668
# Epoch 75/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9118 - loss: 0.2442 - val_accuracy: 0.7833 - val_loss: 0.7317
# Epoch 76/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9008 - loss: 0.2797 - val_accuracy: 0.8000 - val_loss: 0.7139
# Epoch 77/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9155 - loss: 0.2087 - val_accuracy: 0.8611 - val_loss: 0.5077
# Epoch 78/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9242 - loss: 0.1945 - val_accuracy: 0.7778 - val_loss: 0.6205
# Epoch 79/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9151 - loss: 0.2732 - val_accuracy: 0.8111 - val_loss: 0.6422
# Epoch 80/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8877 - loss: 0.3833 - val_accuracy: 0.8278 - val_loss: 0.5910
# Epoch 81/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9079 - loss: 0.2962 - val_accuracy: 0.8389 - val_loss: 0.5173
# Epoch 82/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9186 - loss: 0.2424 - val_accuracy: 0.8611 - val_loss: 0.4556
# Epoch 83/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9113 - loss: 0.2072 - val_accuracy: 0.8500 - val_loss: 0.4753
# Epoch 84/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9364 - loss: 0.1575 - val_accuracy: 0.8444 - val_loss: 0.6877
# Epoch 85/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8931 - loss: 0.2866 - val_accuracy: 0.8556 - val_loss: 0.4897
# Epoch 86/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9357 - loss: 0.2315 - val_accuracy: 0.8222 - val_loss: 0.5637
# Epoch 87/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9255 - loss: 0.2318 - val_accuracy: 0.8611 - val_loss: 0.5547
# Epoch 88/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9199 - loss: 0.2768 - val_accuracy: 0.8056 - val_loss: 0.7919
# Epoch 89/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9047 - loss: 0.2643 - val_accuracy: 0.8889 - val_loss: 0.4807
# Epoch 90/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9398 - loss: 0.1607 - val_accuracy: 0.8611 - val_loss: 0.5807
# Epoch 91/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9420 - loss: 0.1743 - val_accuracy: 0.8889 - val_loss: 0.4617
# Epoch 92/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9503 - loss: 0.1571 - val_accuracy: 0.8278 - val_loss: 0.5965
# Epoch 93/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8950 - loss: 0.2940 - val_accuracy: 0.8722 - val_loss: 0.5836
# Epoch 94/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9346 - loss: 0.2047 - val_accuracy: 0.8556 - val_loss: 0.5112
# Epoch 95/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9198 - loss: 0.2494 - val_accuracy: 0.8500 - val_loss: 0.5408
# Epoch 96/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9268 - loss: 0.2226 - val_accuracy: 0.8611 - val_loss: 0.5161
# Epoch 97/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9661 - loss: 0.1003 - val_accuracy: 0.8778 - val_loss: 0.4983
# Epoch 98/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9494 - loss: 0.1440 - val_accuracy: 0.8833 - val_loss: 0.4572
# Epoch 99/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9454 - loss: 0.1791 - val_accuracy: 0.8778 - val_loss: 0.4765
# Epoch 100/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9367 - loss: 0.2292 - val_accuracy: 0.8278 - val_loss: 0.5365
# Epoch 101/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9226 - loss: 0.1725 - val_accuracy: 0.7944 - val_loss: 0.8621
# Epoch 102/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9201 - loss: 0.1943 - val_accuracy: 0.8722 - val_loss: 0.5794
# Epoch 103/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9259 - loss: 0.1998 - val_accuracy: 0.8889 - val_loss: 0.5352
# Epoch 104/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9617 - loss: 0.1163 - val_accuracy: 0.8722 - val_loss: 0.5685
# Epoch 105/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9586 - loss: 0.0990 - val_accuracy: 0.9000 - val_loss: 0.5720
# Epoch 106/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9677 - loss: 0.1200 - val_accuracy: 0.8611 - val_loss: 0.5605
# Epoch 107/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9264 - loss: 0.2399 - val_accuracy: 0.9056 - val_loss: 0.4738
# Epoch 108/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9343 - loss: 0.1735 - val_accuracy: 0.8389 - val_loss: 0.6372
# Epoch 109/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9188 - loss: 0.2073 - val_accuracy: 0.8278 - val_loss: 0.5175
# Epoch 110/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9344 - loss: 0.1682 - val_accuracy: 0.8389 - val_loss: 0.7795
# Epoch 111/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9043 - loss: 0.3033 - val_accuracy: 0.9111 - val_loss: 0.4233
# Epoch 112/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9422 - loss: 0.1461 - val_accuracy: 0.8944 - val_loss: 0.4226
# Epoch 113/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9597 - loss: 0.1163 - val_accuracy: 0.8778 - val_loss: 0.5448
# Epoch 114/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9674 - loss: 0.1171 - val_accuracy: 0.8778 - val_loss: 0.5440
# Epoch 115/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9645 - loss: 0.1036 - val_accuracy: 0.8778 - val_loss: 0.6238
# Epoch 116/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9371 - loss: 0.1743 - val_accuracy: 0.9111 - val_loss: 0.5125
# Epoch 117/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9513 - loss: 0.1501 - val_accuracy: 0.8667 - val_loss: 0.5358
# Epoch 118/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9000 - loss: 0.2840 - val_accuracy: 0.8611 - val_loss: 0.6023
# Epoch 119/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9532 - loss: 0.1487 - val_accuracy: 0.8556 - val_loss: 0.4347
# Epoch 120/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9333 - loss: 0.2050 - val_accuracy: 0.8444 - val_loss: 0.7288
# Epoch 121/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9573 - loss: 0.1261 - val_accuracy: 0.8722 - val_loss: 0.5439
# Epoch 122/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9745 - loss: 0.0792 - val_accuracy: 0.9000 - val_loss: 0.5724
# Epoch 123/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9715 - loss: 0.0769 - val_accuracy: 0.9000 - val_loss: 0.5538
# Epoch 124/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9447 - loss: 0.1462 - val_accuracy: 0.8222 - val_loss: 0.6790
# Epoch 125/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9520 - loss: 0.1515 - val_accuracy: 0.8278 - val_loss: 0.7228
# Epoch 126/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9365 - loss: 0.1981 - val_accuracy: 0.8778 - val_loss: 0.4248
# Epoch 127/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9577 - loss: 0.1596 - val_accuracy: 0.8889 - val_loss: 0.3854
# Epoch 128/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9000 - loss: 0.2495 - val_accuracy: 0.8500 - val_loss: 0.6132
# Epoch 129/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9225 - loss: 0.2249 - val_accuracy: 0.8389 - val_loss: 0.7315
# Epoch 130/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9545 - loss: 0.1491 - val_accuracy: 0.8778 - val_loss: 0.5293
# Epoch 131/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9463 - loss: 0.1384 - val_accuracy: 0.8611 - val_loss: 0.6522
# Epoch 132/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9584 - loss: 0.1454 - val_accuracy: 0.8333 - val_loss: 0.4341
# Epoch 133/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9448 - loss: 0.1768 - val_accuracy: 0.8944 - val_loss: 0.5018
# Epoch 134/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9808 - loss: 0.0719 - val_accuracy: 0.8944 - val_loss: 0.5734
# Epoch 135/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9718 - loss: 0.0859 - val_accuracy: 0.8944 - val_loss: 0.5659
# Epoch 136/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9601 - loss: 0.1094 - val_accuracy: 0.8778 - val_loss: 0.5453
# Epoch 137/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9559 - loss: 0.1296 - val_accuracy: 0.8778 - val_loss: 0.6433
# Epoch 138/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9589 - loss: 0.0940 - val_accuracy: 0.8722 - val_loss: 0.6226
# Epoch 139/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9606 - loss: 0.1066 - val_accuracy: 0.8667 - val_loss: 0.5118
# Epoch 140/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9429 - loss: 0.1594 - val_accuracy: 0.8389 - val_loss: 0.6838
# Epoch 141/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9248 - loss: 0.2401 - val_accuracy: 0.7944 - val_loss: 0.7986
# Epoch 142/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9259 - loss: 0.2135 - val_accuracy: 0.8389 - val_loss: 0.7075
# Epoch 143/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9545 - loss: 0.1292 - val_accuracy: 0.8778 - val_loss: 0.4389
# Epoch 144/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9853 - loss: 0.0691 - val_accuracy: 0.9167 - val_loss: 0.4447
# Epoch 145/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9884 - loss: 0.0536 - val_accuracy: 0.9000 - val_loss: 0.5107
# Epoch 146/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9677 - loss: 0.0985 - val_accuracy: 0.8833 - val_loss: 0.5768
# Epoch 147/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9724 - loss: 0.0848 - val_accuracy: 0.8833 - val_loss: 0.6904
# Epoch 148/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9636 - loss: 0.0998 - val_accuracy: 0.8944 - val_loss: 0.5338
# Epoch 149/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9736 - loss: 0.0870 - val_accuracy: 0.8389 - val_loss: 0.6901
# Epoch 150/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9682 - loss: 0.1125 - val_accuracy: 0.8722 - val_loss: 0.6270

# %%
model.save("D:/3year/1sem/MLDL/Assignment 1/code/models/model2.keras")

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Find the epoch with the highest validation accuracy
best_epoch = val_accuracy.index(max(val_accuracy)) + 1  # Add 1 because epochs are 1-indexed

print(f"Best Accuracy: {accuracy[best_epoch-1]:.4f} at Epoch {best_epoch}")
print(f"Best Validation Accuracy: {val_accuracy[best_epoch-1]:.4f} at Epoch {best_epoch}")
# Out:
# Best Accuracy: 0.9681 at Epoch 114
# Best Validation Accuracy: 0.9111 at Epoch 114

# %%
y_pred_probs = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_true = y_test

conf_matrix = confusion_matrix(y_true, y_pred_labels)

# Calculate class weights to account for imbalanced classes (optional)
weights = class_weight.compute_sample_weight('balanced', y_true)

# Normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Get class names from your data
classes = ["Class1", "Class2", "Class3", "Class4", "Class5", "Class6"]  # Replace with your actual class names

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, annot=True, fmt=".2f", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 6/6 [==============================] - 4s 569ms/step

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
